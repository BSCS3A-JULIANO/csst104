# %% [markdown]
# #**1. import libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #**2. importing csv**

# %%
data = pd.read_csv('Lesson_4_student_grades_dataset 3.csv')
data
# Out:
#      Hours_of_Study  Attendance_Percentage  Previous_Exam_Scores  \
# 0          4.370861              75.553988             63.085284
# 1          9.556429              86.257028             62.348940
# 2          7.587945              96.188375             95.312729
# 3          6.387926              91.966747             62.477310
# 4          2.404168              94.196834             63.597486
# ..              ...                    ...                   ...
# 995        1.824239              89.708655             93.264788
# 996        9.255822              98.698439             57.863660
# 997        2.231368              72.068740             65.489393
# 998        9.552136              71.711642             64.502277
# 999        5.014052              78.465612             93.570702
#
#      Extracurricular_Activities  Travel_Time_to_School     Grades
# 0                             0              24.325977  31.494329
# ...

# %% [markdown]
# #**3. visualizing the data**

# %%
plt.scatter(data['Previous_Exam_Scores'],data['Grades'],color='gray')
plt.xlabel('Independent variable (X)')
plt.ylabel('Dependent variable (Y)')
plt.title('Scatter plot of data')
plt.show()

# %% [markdown]
# #**4. Preparing data for modeling**

# %%
X = data[['Previous_Exam_Scores']] #independent variable
Y = data[['Grades']] #dependent variable

# %% [markdown]
# #**5. Fitting Linear regression model**

# %%
model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# #**6. getting model coefficient**

# %%
slope = model.coef_[0]

intercept = model.intercept_

print('slope :',slope)
print('intercept :',intercept)
# Out:
# slope : [0.2556363]
# intercept : [16.98814303]

# %% [markdown]
# #**7. visualizing linear regression**

# %%
plt.scatter(X,Y,color='gray')
plt.plot(X,model.predict(X),color='red')
plt.xlabel('Independent variable (X)')
plt.ylabel('Dependent variable (Y)')
plt.title('Scatter plot of data')
plt.show()

# %% [markdown]
# #**8. Making predictions**

# %%
new_X = [[np.random.randint(100,200)]]

predicted_Y = model.predict(new_X)

print('Value of X:', new_X)
print('Predicted Value of Y:', predicted_Y)
# Out:
# Value of X: [[163]]
# Predicted Value of Y: [[100.60941698]]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
